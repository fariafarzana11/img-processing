# %% [markdown]
# <a href="https://colab.research.google.com/github/fariafarzana11/img-processing/blob/main/Color_Changed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

image_path = '/content/drive/MyDrive/image_processing/flower.jpg'
image = plt.imread(image_path)

plt.imshow(image)

plt.axis("off")
plt.show()

# %%
image.shape
# Out:
# (942, 564, 3)

# %%
print(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x942 at 0x79B51D6D7FD0>

# %%
import cv2
cv2.imread(image_path)
# Out:
# array([[[ 17,  41,  11],
#         [ 17,  41,  11],
#         [ 16,  39,  11],
#         ...,
#         [ 24,  49,  29],
#         [ 24,  49,  29],
#         [ 24,  49,  29]],
#
#        [[ 12,  36,   6],
#         [ 12,  36,   6],
#         [ 13,  36,   8],
#         ...,
#         [ 25,  50,  30],
#         [ 24,  49,  29],
#         [ 24,  49,  29]],
#
#        [[ 10,  34,   4],
#         [ 10,  34,   4],
#         [ 11,  34,   6],
#         ...,
#         [ 25,  51,  28],
#         [ 25,  51,  28],
#         [ 25,  51,  28]],
#
#        ...,
#
#        [[ 15, 153,  95],
#         [  0, 133,  76],
#         [  0, 122,  66],
#         ...,
#         [ 37, 174, 123],
#         [ 37, 172, 122],
#         [ 34, 171, 120]],
#
#        [[ 16, 153,  97],
#         [  0, 133,  76],
#         [  0, 122,  66],
#         ...,
#         [ 54, 189, 139],
#         [ 55, 188, 138],
#         [ 49, 184, 134]],
#
#        [[ 17, 154,  98],
#         [  0, 132,  76],
#         [  0, 122,  66],
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = '/content/drive/MyDrive/image_processing/flower.jpg'

image = Image.open(image_path)

plt.imshow(image)

# %%
image = cv2.imread('/content/drive/MyDrive/image_processing/flower.jpg')
blue, green, red = cv2.split(image)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure (figsize=(6, 10))

plt.subplot(2, 2, 1)
plt.imshow(rgb)
plt.title('RGB Channel')

plt.subplot(2, 2, 2)
plt.imshow(blue, cmap='gray')
plt.title('Blue Channel')

plt.subplot(2, 2, 3)
plt.imshow(green, cmap='gray')
plt.title('Green Channel')

plt.subplot(2, 2, 4)
plt.imshow(red, cmap='gray')
plt.title('Red Channel')
# Out:
# Text(0.5, 1.0, 'Red Channel')

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Original Image')

plt.subplot(1, 3, 2)
plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.title('Grayscale Image')

plt.subplot(1, 3, 3)
plt.imshow(hsv_image)
plt.axis('off')
plt.title('HSV Image')

plt.show()
